# %%
# !pip install pytube
# Out:
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      --------------------------------- ---- 51.2/57.6 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 57.6/57.6 kB 763.8 kB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)

# %% [markdown]
# ## List all the url of the videos

# %%
from pytube import YouTube
from pytube import Search

video_names = ['Rockit – Herbie Hancock', 'Thriller – Michael Jackson', 'Girls Just Want to Have Fun – Cyndi Lauper', 'Every Breath You Take – The Police', 'Dont Come Around Here No More – Tom Petty and the Heartbreakers', 'California Girls – David Lee Roth', 'Just a Gigolo / I Aint Got Nobody – David Lee Roth', 'We Are the World – USA for Africa', 'Take On Me – a-ha', 'Cry – Godley & Creme', 'Addicted to Love – Robert Palmer']

def get_video_url(video_name):
    try:
        search_query = video_name + ' YouTube'
        search = Search(search_query)
        video = search.results[0]
        return video.watch_url
    except Exception as e:
        print(f"Could not find URL for '{video_name}': {e}")
        return None

video_urls = {}
for video_name in video_names:
    url = get_video_url(video_name)
    if url:
        video_urls[video_name] = url

for video_name, url in video_urls.items():
    print(f"Video Name: {video_name} - URL: {url}")
# Out:
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Rockit – Herbie Hancock YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Rockit – Herbie Hancock YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Thriller – Michael Jackson YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Thriller – Michael Jackson YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# ...

# %% [markdown]
# ## Process the output into URL only

# %%
import re

video_urls = [
    'Video Name: Rockit – Herbie Hancock - URL: https://youtube.com/watch?v=GHhD4PD75zY',
    'Video Name: Thriller – Michael Jackson - URL: https://youtube.com/watch?v=sOnqjkJTMaA',
    'Video Name: Girls Just Want to Have Fun – Cyndi Lauper - URL: https://youtube.com/watch?v=PIb6AZdTr-A',
    'Video Name: Every Breath You Take – The Police - URL: https://youtube.com/watch?v=OMOGaugKpzs',
    'Video Name: Dont Come Around Here No More – Tom Petty and the Heartbreakers - URL: https://youtube.com/watch?v=h0JvF9vpqx8',
    'Video Name: California Girls – David Lee Roth - URL: https://youtube.com/watch?v=-JpM7i0yaz0',
    'Video Name: Just a Gigolo / I Aint Got Nobody – David Lee Roth - URL: https://youtube.com/watch?v=Tg2rrMwfgB0',
    'Video Name: We Are the World – USA for Africa - URL: https://youtube.com/watch?v=9AjkUyX0rVw',
    'Video Name: Take On Me – a-ha - URL: https://youtube.com/watch?v=djV11Xbc914',
    'Video Name: Cry – Godley & Creme - URL: https://youtube.com/watch?v=6a_PRcVYX7g',
    'Video Name: Addicted to Love – Robert Palmer - URL: https://youtube.com/watch?v=XcATvu5f9vE'
]

video_ids_with_url = [f'https://youtube.com/watch?v={url.split("v=")[-1]}' for url in video_urls]

for video_id_with_url in video_ids_with_url:
    print(video_id_with_url)
# Out:
# https://youtube.com/watch?v=GHhD4PD75zY
# https://youtube.com/watch?v=sOnqjkJTMaA
# https://youtube.com/watch?v=PIb6AZdTr-A
# https://youtube.com/watch?v=OMOGaugKpzs
# https://youtube.com/watch?v=h0JvF9vpqx8
# https://youtube.com/watch?v=-JpM7i0yaz0
# https://youtube.com/watch?v=Tg2rrMwfgB0
# https://youtube.com/watch?v=9AjkUyX0rVw
# https://youtube.com/watch?v=djV11Xbc914
# https://youtube.com/watch?v=6a_PRcVYX7g
# https://youtube.com/watch?v=XcATvu5f9vE

# %% [markdown]
# ## Batch download'em

# %%
from pytube import YouTube

video_urls = {
    'https://youtube.com/watch?v=GHhD4PD75zY',
    'https://youtube.com/watch?v=sOnqjkJTMaA',
    'https://youtube.com/watch?v=PIb6AZdTr-A',
    'https://youtube.com/watch?v=OMOGaugKpzs',
    'https://youtube.com/watch?v=h0JvF9vpqx8',
    'https://youtube.com/watch?v=-JpM7i0yaz0',
    'https://youtube.com/watch?v=Tg2rrMwfgB0',
    'https://youtube.com/watch?v=9AjkUyX0rVw',
    'https://youtube.com/watch?v=djV11Xbc914',
    'https://youtube.com/watch?v=6a_PRcVYX7g',
    'https://youtube.com/watch?v=XcATvu5f9vE',
}

download_dir = 'D:\DATABASE\Music_Videos'

for url in video_urls:
    try:
        yt = YouTube(url)

        video_stream = yt.streams.get_highest_resolution()

        print(f"Downloading: {yt.title}")
        video_stream.download(download_dir)

        print(f"Download of '{yt.title}' complete.")
    except Exception as e:
        print(f"Could not download '{url}': {e}")

print("Batch download complete!")
# Out:
# Downloading: Don't Come Around Here No More
# Download of 'Don't Come Around Here No More' complete.
# Downloading: Girls Just Want To Have Fun (Official Video)
# Download of 'Girls Just Want To Have Fun (Official Video)' complete.
# Downloading: Just a Gigolo / I Ain't Got Nobody
# Download of 'Just a Gigolo / I Ain't Got Nobody' complete.
# Downloading: Rockit (Official Video)
# Download of 'Rockit (Official Video)' complete.
# Downloading: Thriller (Official 4K Video)
# Download of 'Thriller (Official 4K Video)' complete.
# Downloading: David Lee Roth - California Girls (1985) (Music Video - MTV Version) WIDESCREEN 1080p
# Download of 'David Lee Roth - California Girls (1985) (Music Video - MTV Version) WIDESCREEN 1080p' complete.
# Downloading: We Are the World
# Download of 'We Are the World' complete.
# Downloading: Take On Me
# Download of 'Take On Me' complete.
# Downloading: Addicted To Love
# Download of 'Addicted To Love' complete.
# Downloading: Cry
# ...

# %% [markdown]
# # Keep Downloading

# %%
from pytube import YouTube
from pytube import Search

video_names = ['Road to Nowhere – Talking Heads', 'Land of Confusion – Genesis', 'The Boy in the Bubble – Paul Simon', 'With or Without You – U2', 'Higher Love – Steve Winwood', 'When We Was Fab – George Harrison', 'Tunnel of Love – Bruce Springsteen', 'I Still Havent Found What Im Looking For – U2', 'Where the Streets Have No Name – U2', 'She Drives Me Crazy – Fine Young Cannibals']

def get_video_url(video_name):
    try:
        search_query = video_name + ' YouTube'
        search = Search(search_query)
        video = search.results[0]
        return video.watch_url
    except Exception as e:
        print(f"Could not find URL for '{video_name}': {e}")
        return None

video_urls = {}
for video_name in video_names:
    url = get_video_url(video_name)
    if url:
        video_urls[video_name] = url

for video_name, url in video_urls.items():
    print(f"Video Name: {video_name} - URL: {url}")
# Out:
# Unexpected renderer encountered.
# Renderer name: dict_keys(['adSlotRenderer'])
# Search term: Road to Nowhere – Talking Heads YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Land of Confusion – Genesis YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Land of Confusion – Genesis YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: With or Without You – U2 YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# ...

# %%
import re

video_urls = [
    'Video Name: Road to Nowhere – Talking Heads - URL: https://youtube.com/watch?v=LQiOA7euaYA',
    'Video Name: Land of Confusion – Genesis - URL: https://youtube.com/watch?v=TlBIa8z_Mts',
    'Video Name: The Boy in the Bubble – Paul Simon - URL: https://youtube.com/watch?v=Uy5T6s25XK4',
    'Video Name: With or Without You – U2 - URL: https://youtube.com/watch?v=ujNeHIo7oTE',
    'Video Name: Higher Love – Steve Winwood - URL: https://youtube.com/watch?v=k9olaIio3l8',
    'Video Name: When We Was Fab – George Harrison - URL: https://youtube.com/watch?v=AVu6nPTVbBQ',
    'Video Name: Tunnel of Love – Bruce Springsteen - URL: https://youtube.com/watch?v=M4K7XZGeHTE',
    'Video Name: I Still Havent Found What Im Looking For – U2 - URL: https://youtube.com/watch?v=e3-5YC_oHjE',
    'Video Name: Where the Streets Have No Name – U2 - URL: https://youtube.com/watch?v=GzZWSrr5wFI',
    'Video Name: She Drives Me Crazy – Fine Young Cannibals - URL: https://youtube.com/watch?v=UtvmTu4zAMg'
]

video_ids_with_url = [f'https://youtube.com/watch?v={url.split("v=")[-1]}' for url in video_urls]

for video_id_with_url in video_ids_with_url:
    print(video_id_with_url)
# Out:
# https://youtube.com/watch?v=LQiOA7euaYA
# https://youtube.com/watch?v=TlBIa8z_Mts
# https://youtube.com/watch?v=Uy5T6s25XK4
# https://youtube.com/watch?v=ujNeHIo7oTE
# https://youtube.com/watch?v=k9olaIio3l8
# https://youtube.com/watch?v=AVu6nPTVbBQ
# https://youtube.com/watch?v=M4K7XZGeHTE
# https://youtube.com/watch?v=e3-5YC_oHjE
# https://youtube.com/watch?v=GzZWSrr5wFI
# https://youtube.com/watch?v=UtvmTu4zAMg

# %%
from pytube import YouTube

video_urls = {
    'https://youtube.com/watch?v=LQiOA7euaYA',
    'https://youtube.com/watch?v=TlBIa8z_Mts',
    'https://youtube.com/watch?v=Uy5T6s25XK4',
    'https://youtube.com/watch?v=ujNeHIo7oTE',
    'https://youtube.com/watch?v=k9olaIio3l8',
    'https://youtube.com/watch?v=AVu6nPTVbBQ',
    'https://youtube.com/watch?v=M4K7XZGeHTE',
    'https://youtube.com/watch?v=e3-5YC_oHjE',
    'https://youtube.com/watch?v=GzZWSrr5wFI',
    'https://youtube.com/watch?v=UtvmTu4zAMg'
}

download_dir = 'D:\DATABASE\Music_Videos'

for url in video_urls:
    try:
        yt = YouTube(url)

        video_stream = yt.streams.get_highest_resolution()

        print(f"Downloading: {yt.title}")
        video_stream.download(download_dir)

        print(f"Download of '{yt.title}' complete.")
    except Exception as e:
        print(f"Could not download '{url}': {e}")

print("Batch download complete!")
# Out:
# Downloading: Where The Streets Have No Name Video
# Download of 'Where The Streets Have No Name Video' complete.
# Downloading: When We Was Fab
# Download of 'When We Was Fab' complete.
# Downloading: The Boy in the Bubble
# Download of 'The Boy in the Bubble' complete.
# Downloading: Road to Nowhere
# Download of 'Road to Nowhere' complete.
# Downloading: With Or Without You (Official Music Video)
# Download of 'With Or Without You (Official Music Video)' complete.
# Downloading: She Drives Me Crazy
# Download of 'She Drives Me Crazy' complete.
# Downloading: Higher Love
# Download of 'Higher Love' complete.
# Downloading: Tunnel of Love (Official Video)
# Download of 'Tunnel of Love (Official Video)' complete.
# Downloading: I Still Haven't Found What I'm Looking For
# Download of 'I Still Haven't Found What I'm Looking For' complete.
# Downloading: Land Of Confusion (Official Music Video)
# Download of 'Land Of Confusion (Official Music Video)' complete.
# ...

# %%
'Leave Me Alone – Michael Jackson', 'Like a Prayer – Madonna', 'Roll with It – Steve Winwood', 'Janie's Got a Gun – Aerosmith', 'The End of the Innocence – Don Henley', 'Vogue – Madonna', 'Gonna Make You Sweat (Everybody Dance Now) – C+C Music Factory', 'Groove Is in the Heart – Deee-Lite', 'I Touch Myself – Divinyls', 'Wicked Game – Chris Isaak', 'Silent Lucidity – Queensrÿche', 'Let's Get Rocked – Def Leppard', 'Smells Like Teen Spirit – Nirvana', 'Under the Bridge – Red Hot Chili Peppers', 'Livin' on the Edge – Aerosmith', 'Free Your Mind – En Vogue', 'Digging in the Dirt – Peter Gabriel', 'Man on the Moon – R.E.M.', 'Sabotage – Beastie Boys', 'Heart-Shaped Box – Nirvana'

# %%
from pytube import YouTube
from pytube import Search

video_names = ['Leave Me Alone – Michael Jackson', 'Like a Prayer – Madonna', 'Roll with It – Steve Winwood', 'Janies Got a Gun – Aerosmith', 'The End of the Innocence – Don Henley', 'Vogue – Madonna', 'Gonna Make You Sweat (Everybody Dance Now) – C+C Music Factory', 'Groove Is in the Heart – Deee-Lite', 'I Touch Myself – Divinyls', 'Wicked Game – Chris Isaak', 'Silent Lucidity – Queensrÿche', 'Lets Get Rocked – Def Leppard', 'Smells Like Teen Spirit – Nirvana', 'Under the Bridge – Red Hot Chili Peppers', 'Livin on the Edge – Aerosmith', 'Free Your Mind – En Vogue', 'Digging in the Dirt – Peter Gabriel', 'Man on the Moon – R.E.M.', 'Sabotage – Beastie Boys', 'Heart-Shaped Box – Nirvana']

def get_video_url(video_name):
    try:
        search_query = video_name + ' YouTube'
        search = Search(search_query)
        video = search.results[0]
        return video.watch_url
    except Exception as e:
        print(f"Could not find URL for '{video_name}': {e}")
        return None

video_urls = {}
for video_name in video_names:
    url = get_video_url(video_name)
    if url:
        video_urls[video_name] = url

for video_name, url in video_urls.items():
    print(f"Video Name: {video_name} - URL: {url}")
# Out:
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Leave Me Alone – Michael Jackson YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['adSlotRenderer'])
# Search term: Leave Me Alone – Michael Jackson YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['adSlotRenderer'])
# Search term: Leave Me Alone – Michael Jackson YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Leave Me Alone – Michael Jackson YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# ...

# %%
import re

video_urls = [
    'Video Name: Leave Me Alone – Michael Jackson - URL: https://youtube.com/watch?v=crbFmpezO4A',
    'Video Name: Like a Prayer – Madonna - URL: https://youtube.com/watch?v=79fzeNUqQbQ',
    'Video Name: Roll with It – Steve Winwood - URL: https://youtube.com/watch?v=u_vkKozA8OI',
    'Video Name: Janies Got a Gun – Aerosmith - URL: https://youtube.com/watch?v=RqQn2ADZE1A',
    'Video Name: The End of the Innocence – Don Henley - URL: https://youtube.com/watch?v=0ON7IJJq0t0',
    'Video Name: Vogue – Madonna - URL: https://youtube.com/watch?v=GuJQSAiODqI',
    'Video Name: Gonna Make You Sweat (Everybody Dance Now) – C+C Music Factory - URL: https://youtube.com/watch?v=LaTGrV58wec',
    'Video Name: Groove Is in the Heart – Deee-Lite - URL: https://youtube.com/watch?v=etviGf1uWlg',
    'Video Name: I Touch Myself – Divinyls - URL: https://youtube.com/watch?v=wv-34w8kGPM',
    'https://youtube.com/watch?v=i7iQbBbMAFE',
    'https://youtube.com/watch?v=X0C3DHp36zc',
    'https://youtube.com/watch?v=dLxpNiF0YKs',
    'https://youtube.com/watch?v=z5rRZdiu1UE',
    'https://youtube.com/watch?v=n6P0SitRwy8',
}

download_dir = 'D:\DATABASE\Music_Videos'

for url in video_urls:
    try:
        yt = YouTube(url)

        video_stream = yt.streams.get_highest_resolution()

        print(f"Downloading: {yt.title}")
        video_stream.download(download_dir)

        print(f"Download of '{yt.title}' complete.")
    except Exception as e:
        print(f"Could not download '{url}': {e}")

print("Batch download complete!")
# Out:
# Downloading: Gonna Make You Sweat (Everybody Dance Now) (Official HD Video)
# Download of 'Gonna Make You Sweat (Everybody Dance Now) (Official HD Video)' complete.
# Downloading: Leave Me Alone (Official Video)
# Download of 'Leave Me Alone (Official Video)' complete.
# Downloading: Janie's Got A Gun David Fincher Cut
# Download of 'Janie's Got A Gun David Fincher Cut' complete.
# Downloading: Roll With It
# Download of 'Roll With It' complete.
# Downloading: Wicked Game
# Download of 'Wicked Game' complete.
# Downloading: Silent Lucidity (Official Music Video)
# Download of 'Silent Lucidity (Official Music Video)' complete.
# Downloading: Heart-Shaped Box
# Download of 'Heart-Shaped Box' complete.
# Downloading: Vogue
# Download of 'Vogue' complete.
# Downloading: Free Your Mind
# Download of 'Free Your Mind' complete.
# Downloading: Man on the Moon (Orchestral)
# Download of 'Man on the Moon (Orchestral)' complete.
# Downloading: Groove Is In The Heart
# ...

# %%
'You Might Think - The Cars', 'The Boys of Summer - Don Henley', 'Money for Nothing - Dire Straits', 'Sledgehammer - Peter Gabriel', 'Need You Tonight - INXS', 'Mediate - INXS', 'This Notes for You - Neil Young', 'Nothing Compares 2 U" - Sinéad OConnor', 'Losing My Religion - R.E.M.', 'Right Now" - Van Halen', 'Jeremy" - Pearl Jam', 'Cryin - Aerosmith', 'Waterfalls - TLC', 'Tonight, Tonight - The Smashing Pumpkins', 'Virtual Insanity - Jamiroquai', 'Ray of Light - Madonna', 'Doo Wop (That Thing) - Lauryn Hill', 'The Real Slim Shady - Eminem', 'Lady Marmalade" - Christina Aguilera, Lil Kim, Mýa, and P!nk'

# %%
from pytube import YouTube
from pytube import Search

video_names = ['You Might Think - The Cars', 'The Boys of Summer - Don Henley', 'Money for Nothing - Dire Straits', 'Sledgehammer - Peter Gabriel', 'Need You Tonight - INXS', 'Mediate - INXS', 'This Notes for You - Neil Young', 'Nothing Compares 2 U" - Sinéad OConnor', 'Losing My Religion - R.E.M.', 'Right Now" - Van Halen', 'Jeremy" - Pearl Jam', 'Cryin - Aerosmith', 'Waterfalls - TLC', 'Tonight, Tonight - The Smashing Pumpkins', 'Virtual Insanity - Jamiroquai', 'Ray of Light - Madonna', 'Doo Wop (That Thing) - Lauryn Hill', 'The Real Slim Shady - Eminem', 'Lady Marmalade" - Christina Aguilera, Lil Kim, Mýa, and P!nk']

def get_video_url(video_name):
    try:
        search_query = video_name + ' YouTube'
        search = Search(search_query)
        video = search.results[0]
        return video.watch_url
    except Exception as e:
        print(f"Could not find URL for '{video_name}': {e}")
        return None

video_urls = {}
for video_name in video_names:
    url = get_video_url(video_name)
    if url:
        video_urls[video_name] = url

for video_name, url in video_urls.items():
    print(f"Video Name: {video_name} - URL: {url}")
# Out:
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term
# https://youtube.com/watch?v=4JkIs37a2JE
# https://youtube.com/watch?v=x3ov9USxVxY
# https://youtube.com/watch?v=T6QKqFPRZSA
# https://youtube.com/watch?v=rkqMbsmLrtA
# https://youtube.com/watch?v=RQa7SvVCdZk

# %%
from pytube import YouTube

video_urls = {
    'https://youtube.com/watch?v=3dOx510kyOs',
    'https://youtube.com/watch?v=6RUIeX6UCT8',
    'https://youtube.com/watch?v=wTP2RUD_cL0',
    'https://youtube.com/watch?v=OJWJE0x7T4Q',
    'https://youtube.com/watch?v=w-rv2BQa2OU',
    'https://youtube.com/watch?v=Pr-Vfnd7Yno',
    'https://youtube.com/watch?v=KSSvzCNBvlQ',
    'https://youtube.com/watch?v=0-EF60neguk',
    'https://youtube.com/watch?v=xwtdhWltSIg',
    'https://youtube.com/watch?v=gU7d2EHV_OQ',
    'https://youtube.com/watch?v=bQtPzo-7AHs',
    'https://youtube.com/watch?v=qfNmyxV2Ncw',
    'https://youtube.com/watch?v=8WEtxJ4-sh4',
    'https://youtube.com/watch?v=NOG3eus4ZSo',
    'https://youtube.com/watch?v=4JkIs37a2JE',
    'https://youtube.com/watch?v=x3ov9USxVxY',
    'https://youtube.com/watch?v=T6QKqFPRZSA',
    'https://youtube.com/watch?v=rkqMbsmLrtA',
    'https://youtube.com/watch?v=RQa7SvVCdZ'
}

download_dir = 'D:\DATABASE\Music_Videos'

for url in video_urls:
    try:
        yt = YouTube(url)

        video_stream = yt.streams.get_highest_resolution()

        print(f"Downloading: {yt.title}")
        video_stream.download(download_dir)

        print(f"Download of '{yt.title}' complete.")
    except Exception as e:
        print(f"Could not download '{url}': {e}")

print("Batch download complete!")
# Out:
# Downloading: Eminem - The Real Slim Shady (Lyrics)
# Download of 'Eminem - The Real Slim Shady (Lyrics)' complete.
# Downloading: Nothing Compares 2 U
# Download of 'Nothing Compares 2 U' complete.
# Downloading: Mediate
# Download of 'Mediate' complete.
# Downloading: You Might Think
# Download of 'You Might Think' complete.
# Downloading: Cryin'
# Download of 'Cryin'' complete.
# Downloading: Losing My Religion
# Download of 'Losing My Religion' complete.
# Downloading: The Boys Of Summer (Official Music Video)
# Download of 'The Boys Of Summer (Official Music Video)' complete.
# Downloading: Tonight, Tonight (Official Music Video)
# Download of 'Tonight, Tonight (Official Music Video)' complete.
# Downloading: Waterfalls (Official HD Video)
# Download of 'Waterfalls (Official HD Video)' complete.
# Downloading: Virtual Insanity (Official Video)
# Download of 'Virtual Insanity (Official Video)' complete.
# Downloading: Need You Tonight
# Download of 'Need You Tonight' complete.
# ...

# %%
from pytube import YouTube
from pytube import Search

video_names = ['Livin on the Edge – Aerosmith', 'Free Your Mind – En Vogue', 'Digging in the Dirt – Peter Gabriel', 'Man on the Moon – R.E.M.', 'Sabotage – Beastie Boys', 'Heart-Shaped Box – Nirvana', 'Everybody Hurts – R.E.M.', 'Basket Case – Green Day', 'Scream – Michael Jackson and Janet Jackson', 'Buddy Holly – Weezer', 'Tha Crossroads – Bone Thugs-n-Harmony', 'Big Me – Foo Fighters', 'Ironic – Alanis Morissette', 'The New Pollution – Beck', 'You Were Meant for Me – Jewel', 'The Perfect Drug – Nine Inch Nails', 'Dont Speak – No Doubt', 'The Boy is Mine – Brandy and Monica', 'Its All About the Benjamins (Rock Remix) – Puff Daddy (featuring the LOX, Lil Kim, The Notorious B.I.G. and Fuzzbubble)', 'Gettin Jiggy wit It – Will Smith']

def get_video_url(video_name):
    try:
        search_query = video_name + ' YouTube'
        search = Search(search_query)
        video = search.results[0]
        return video.watch_url
    except Exception as e:
        print(f"Could not find URL for '{video_name}': {e}")
        return None

video_urls = {}
for video_name in video_names:
    url = get_video_url(video_name)
    if url:
        video_urls[video_name] = url

for video_name, url in video_urls.items():
    print(f"Video Name: {video_name} - URL: {url}")
# Out:
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Free Your Mind – En Vogue YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Digging in the Dirt – Peter Gabriel YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Heart-Shaped Box – Nirvana YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Heart-Shaped Box – Nirvana YouTube
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# ...

# %%
from pytube import YouTube

video_urls = {
    'https://youtube.com/watch?v=7nqcL0mjMjw',
    'https://youtube.com/watch?v=i7iQbBbMAFE',
    'https://youtube.com/watch?v=X0C3DHp36zc',
    'https://youtube.com/watch?v=dLxpNiF0YKs',
    'https://youtube.com/watch?v=z5rRZdiu1UE',
    'https://youtube.com/watch?v=n6P0SitRwy8',
    'https://youtube.com/watch?v=5rOiW_xY-kc',
    'https://youtube.com/watch?v=NUTGr5t3MoY',
    'https://youtube.com/watch?v=0P4A1K4lXDo',
    'https://youtube.com/watch?v=kemivUKb4f4',
    'https://youtube.com/watch?v=VMYAEHE2GrM',
    'https://youtube.com/watch?v=pLdJQFTnZfA',
    'https://youtube.com/watch?v=Jne9t8sHpUc',
    'https://youtube.com/watch?v=uxugaMpt1vU',
    'https://youtube.com/watch?v=4WW4qcmrJ3E',
    'https://youtube.com/watch?v=dn3j6-yQKWQ',
    'https://youtube.com/watch?v=TR3Vdo5etCQ',
    'https://youtube.com/watch?v=qSIOp_K5GMw',
    'https://youtube.com/watch?v=PaEMpAlppNE',
    'https://youtube.com/watch?v=3JcmQONgXJM',
}

download_dir = 'D:\DATABASE\Music_Videos'

for url in video_urls:
    try:
        yt = YouTube(url)

        video_stream = yt.streams.get_highest_resolution()

        print(f"Downloading: {yt.title}")
        video_stream.download(download_dir)

        print(f"Download of '{yt.title}' complete.")
    except Exception as e:
        print(f"Could not download '{url}': {e}")

print("Batch download complete!")
# Out:
# Downloading: You Were Meant For Me
# Download of 'You Were Meant For Me' complete.
# Downloading: Puff Daddy - It's All About The Benjamins (Rock Remix) (Official Music Video) [HD]
# Download of 'Puff Daddy - It's All About The Benjamins (Rock Remix) (Official Music Video) [HD]' complete.
# Downloading: Ironic
# Download of 'Ironic' complete.
# Downloading: The Boy Is Mine
# Download of 'The Boy Is Mine' complete.
# Downloading: Basket Case
# Download of 'Basket Case' complete.
# Downloading: Don't Speak
# Download of 'Don't Speak' complete.
# Downloading: Everybody Hurts (album Fade)
# Download of 'Everybody Hurts (album Fade)' complete.
# Downloading: Buddy Holly
# Download of 'Buddy Holly' complete.
# Downloading: Heart-Shaped Box
# Download of 'Heart-Shaped Box' complete.
# Downloading: Free Your Mind
# Download of 'Free Your Mind' complete.
# Downloading: The Perfect Drug
# Download of 'The Perfect Drug' complete.
# Downloading: Man on the Moon (Orchestral)
# ...
